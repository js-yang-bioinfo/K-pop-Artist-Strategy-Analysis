# %%
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (2.133.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (2.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (2.19.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.21.12)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.23.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (1.26.16)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\k0707\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas
import pandas as pd
from googleapiclient.discovery import build
 
 
api_key =
video_id = 'ft70sAYrFyY'
 
comments = list()
api_obj = build('youtube', 'v3', developerKey=api_key)
response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()

print(response)
while response:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
 
        if item['snippet']['totalReplyCount'] > 0:
            for reply_item in item['replies']['comments']:
                reply = reply_item['snippet']
                comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
 
    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break
df = pd.DataFrame(comments, columns=['comment', 'author', 'date', 'num_likes'])
df.to_csv('./유튜브댓글/뉴진스_버블검_유튜브_댓글.csv', index=False, encoding='utf-8')
df
# Out:
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'jPb9sc8H3prdx3r4z6GnCAUXPBo', 'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpSklCZ0FFZ1VJcUNBWUFCSUZDSjBnR0FFU0JRaUhJQmdBR0FBaURRb0xDUFNsd2JNR0VKal85M0E=', 'pageInfo': {'totalResults': 100, 'resultsPerPage': 100}, 'items': [{'kind': 'youtube#commentThread', 'etag': '6LMm9klAN0xyLU3dx0SpDVLYKPs', 'id': 'Ugz1wwMuLIOj4aqrunJ4AaABAg', 'snippet': {'channelId': 'UC3IZKseVpdzPSBaWxBxundA', 'videoId': 'ft70sAYrFyY', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'RNR0Wqdyi1SXRcL3Y9QEIzOCPes', 'id': 'Ugz1wwMuLIOj4aqrunJ4AaABAg', 'snippet': {'channelId': 'UC3IZKseVpdzPSBaWxBxundA', 'videoId': 'ft70sAYrFyY', 'textDisplay': '잠시후 6월20일 00시 슈퍼내츄럴 티저2 !!! ❤🧡💛💚💙', 'textOriginal': '잠시후 6월20일 00시 슈퍼내츄럴 티저2 !!! ❤🧡💛💚💙', 'authorDisplayName': '@user-oe8uq1hg5s', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nkHZGZlGwDAAf16_Cy6lhG9gSWWgffWKkdHNQxlqk=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@user-oe8uq1hg5s', 'authorChannelId': {'value': 'UC7OQ09QtKE49e07ew31sbDg'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 1, 'publishedAt': '2024-06-19T11:40:07Z', 'updatedAt': '2024-06-19T11:40:07Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'TTLBpSnDujIDD9OoOkdWnWAD5M0', 'id': 'UgzDmiLC-b8L19EBFY94AaABAg', 'snippet': {'channelId': 'UC3IZKseVpdzPSBaWxBxundA', 'videoId': 'ft70sAYrFyY', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'OOahVNng7GtfzM-R-Aq3qkvHozI', 'id': 'UgzDmiLC-b8L19EBFY94AaABAg', 'snippet': {'channelId': 'UC3IZKseVpdzPSBaWxBxundA', 'videoId': 'ft70sAYrFyY', 'textDisplay': '처음엔 민지가 그렇거 이쁘더니 나중엔 팜하니가 너무 귀엽고 그러고 또 나중엔 모다니가 너무 사랑스럽고 또 나중엔 어린나이에 비해 너무 프로페셔널한 해인이가 너무 멋지고 이쁘고 지금은 해린이가 너어어어무 좋네ㅜ❤<br>어쩜 이리 구멍도 한명없이 다 사랑스럽고 이쁘냐ㅠㅠ❤', 'textOriginal': '처음엔 민지가 그렇거 이쁘더니 나중엔 팜하니가 너무 귀엽고 그러고 또 나중엔 모다니가 너무 사랑스럽고 또 나중엔 어린나이에 비해 너무 프로페셔널한 해인이가 너무 멋지고 이쁘고 지금은 해린이가 너어어어무 좋네ㅜ❤\n어쩜 이리 구멍도 한명없이 다 사랑스럽고 이쁘냐ㅠㅠ❤', 'authorDisplayName': '@user-qc4ls7vv9v', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lbJUPsxBKXfdvQ7sYXvlF2NQ_X8wICFiC2hF_KqtQ=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@user-qc4ls7vv9v', 'authorChannelId': {'value': 'UCvNnukPXtJhb1yRDp9QZEBw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 2, 'publishedAt': '2024-06-19T11:31:41Z', 'updatedAt': '2024-06-19T11:31:41Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'HCabyVpdy57dHfv4NLbxDKvOE-E', 'id': 'UgybdHkfMR3tDVgUaj94AaABAg', 'snippet': {'channelId': 'UC3IZKseVpdzPSBaWxBxundA', 'videoId': 'ft70sAYrFyY', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'Z2Mi6iF2b8Htiz3DAm5mq-lXars', 'id': 'UgybdHkfMR3tDVgUaj94AaABAg', 'snippet': {'channelId': 'UC3IZKseVpdzPSBaWxBxundA', 'videoId': 'ft70sAYrFyY', 'textDisplay': 'its like coming from school on a hot day and finding ur favourite cousins at ur home and spending the day with them in 2016 and recording it', 'textOriginal': 'its like coming from school on a hot day and finding ur favourite cousins at ur home and spending the day with them in 2016 and recording it', 'authorDisplayName': '@izyanchoudhury1026', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m7heFBUZ7Si0QA1kx1WjdZ_2aPQ3AZUNXFsPX7LUJ1OAOPIt2dM4430mdARXwcc-CmHw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/@izyanchoudhury1026', 'authorChannelId': {'value': 'UCHKgpQ27Rst3UfEvuaPxU2Q'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 1, 'publishedAt': '2024-06-19T10:31:54Z', 'updatedAt': '2024-06-19T10:34:10Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'ojezozo-Ogv4zBmXZsiXmpVbiuE', 'id': 'UgywlSUgCoErc9P64oR4AaABAg', 'snippet': {'channelId': 'UC3IZKseVpdzPSBaWxBxundA', 'videoId': 'ft70sAYrFyY', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'YPFtP3SDaARlPCQ-5Xn2F09Y5nI',  ...
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[19], line 24
#      21             comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
#      23 if 'nextPageToken' in response:
# ---> 24     response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=response['nextPageToken'], maxResults=100).execute()
#      25 else:
#      26     break
#
# File c:\Users\k0707\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\k0707\AppData\Local\Programs\Python\Python311\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=ft70sAYrFyY&pageToken=Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNLZ2dHQUFTQlFpSElCZ0FFZ1VJblNBWUFSSUZDSWdnR0FBU0JRaUpJQmdBR0FBaURnb01DS0staHJJR0VPaWJfcXdE&maxResults=100&key=AIzaSyAO9tRvU7NpHKwDcnKbFgJuE5DsAzlGLwA&alt=json returned "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the request's input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid.". Details: "[{'message': "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the request's input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid.", 'domain': 'youtube.commentThread', 'reason': 'processingFailure', 'location': 'body', 'locationType': 'other'}]">

# %%
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import logging

# 로그 설정
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

api_key = 
video_id = 'phuiiNCxRMg'

def get_comments(api_key, video_id):
    comments = []
    try:
        api_obj = build('youtube', 'v3', developerKey=api_key)
        response = api_obj.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            maxResults=100
        ).execute()
        
        while response:
            for item in response['items']:
                comment = item['snippet']['topLevelComment']['snippet']
                comments.append([
                    comment['textDisplay'],
                    comment['authorDisplayName'],
                    comment['publishedAt'],
                    comment['likeCount']
                ])

                if 'replies' in item and item['snippet']['totalReplyCount'] > 0:
                    for reply_item in item['replies']['comments']:
                        reply = reply_item['snippet']
                        comments.append([
                            reply['textDisplay'],
                            reply['authorDisplayName'],
                            reply['publishedAt'],
                            reply['likeCount']
                        ])

            if 'nextPageToken' in response:
                response = api_obj.commentThreads().list(
                    part='snippet,replies',
                    videoId=video_id,
                    pageToken=response['nextPageToken'],
                    maxResults=100
                ).execute()
            else:
                break

    except HttpError as e:
        logger.error(f"HTTP 오류 발생: {e}")
    except Exception as e:
        logger.error(f"오류 발생: {e}")

    return comments

comments = get_comments(api_key, video_id)
df = pd.DataFrame(comments, columns=['comment', 'author', 'date', 'num_likes'])
df.to_csv('./유튜브댓글/에스파_수퍼노바_댓글.csv', index=False, encoding='utf-8')
df
# Out:
# INFO:googleapiclient.discovery_cache:file_cache is only supported with oauth2client<4.0.0
# ERROR:__main__:HTTP 오류 발생: <HttpError 400 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=phuiiNCxRMg&pageToken=Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNKMGdHQUVTQlFpb0lCZ0FFZ1VJaVNBWUFCSUZDSWNnR0FBU0JRaUlJQmdBR0FBaURnb01DSlN5anJJR0VKQ09tZG9D&maxResults=100&key=AIzaSyAO9tRvU7NpHKwDcnKbFgJuE5DsAzlGLwA&alt=json returned "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the request's input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid.". Details: "[{'message': "The API server failed to successfully process the request. While this can be a transient error, it usually indicates that the request's input is invalid. Check the structure of the <code>commentThread</code> resource in the request body to ensure that it is valid.", 'domain': 'youtube.commentThread', 'reason': 'processingFailure', 'location': 'body', 'locationType': 'other'}]">
#                                                  comment             author  \
# 0      <a href="https://www.youtube.com/watch?v=phuii...          @swerty16
# 1                                                    Out   @user-yi5ib1gd5q
# 2                                                  81.2M         @Bblueee59
# 3                                                   SOTY  @justafangirl9016
# 4                             충재의 &#39;와&#39;가 들리는건 나뿐인가     @bobbychoi5005
# ...                                                  ...                ...
# 40787                                 Song of the year ✨           @hirdeux
# 40788                    Aespa yine slayledi ve kudurttu          @arincatw
# 40789             PUURR LOVE THIS SONG STYLE AND CONCEPT         @lizzie404
# 40790         Because of this reason, SM is in the BIG3.         @subjk1453
# 40791                           노래가 재밌어요 ...<br> 자꾸 보게되요      @pandalove993
#
#                        date  num_likes
# 0      2024-06-25T12:23:13Z          0
# 1      2024-06-25T12:01:43Z          0
# 2      2024-06-25T11:52:42Z          0
# 3      2024-06-25T11:50:29Z          0
# 4      2024-06-25T11:44:44Z          0
# ...                     ...        ...
# 40787  2024-05-14T17:02:59Z          3
# 40788  2024-05-14T17:02:54Z          0
# 40789  2024-05-14T17:02:41Z          1
# 40790  2024-05-14T17:02:39Z          1
# 40791  2024-05-14T17:02:13Z          7
#
# [40792 rows x 4 columns]
